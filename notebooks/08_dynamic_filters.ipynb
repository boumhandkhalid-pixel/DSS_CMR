# %% [markdown]
# # Notebook 08 — Dynamic Filters Prototype
#
# This notebook will prototype configurable filters using liquidity, average volume, free-float and weight criteria.

# %%
import pandas as pd

sample = pd.DataFrame({
    'CODE_ISIN': ['MA0000000001', 'MA0000000002'],
    'Liquidity': [2.0, 0.5],
    'Average Volume': [120000, 50000],
    'Free Float': [0.8, 0.2],
    'Weight': [0.15, 0.03],
})
sample
