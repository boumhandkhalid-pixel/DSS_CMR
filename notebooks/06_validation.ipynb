# %% [markdown]
# # Notebook 06 — Validation Prototype
#
# This notebook will prototype validation checks for dates, duplicates, missing values and malformed sheet structures.

# %%
import pandas as pd

sample = pd.DataFrame({
    'Date': ['2024-01-02', '2024-01-02'],
    'CODE_ISIN': ['MA0000000001', 'MA0000000001'],
    'Price': [100.0, None]
})
sample
